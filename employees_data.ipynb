# %% [markdown]
# <a href="https://colab.research.google.com/github/Malihazameer/Multiple-Employees-Data/blob/main/employees_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CODE TO DISPLAY 100 OR 100 EMPLOYEES DATA**

# %%
import random #import random because it allow to have your desire uncountable number of data
import json #import json brcause to display data in dictionary or json format

names = ["maliha", "meheen", "hafsa", "manahil", "zara", "mehr", "aqsa", "kinza"]
departments = ["HR", "Software Engineering", "Marketing", "Sales", "Accounts"]
skills = ["html", "css", "JavaScript", "python", "ai engineer", "data science", "next js"]

employees = []
count=int(input("How much employees data you want?: "))

for i in range(1, count+1):
    experiences = []
    for _ in range(random.randint(1, 3)):  # Each employee has 1 to 3 experiences
        experiences.append({
            "Company_Id": random.choice(["C001", "C002", "C003", "C004","C005","C006","C007","C008","C009","C010"]),
            "Department": random.choice(departments),
            "Salary": f"Rs.{random.randint(40000, 100000)}/-"
        })

    employee = {
        "ID": f"Emp{i}",
        "Name": random.choice(names),
        "Age": random.randint(20, 60),
        "Department": random.choice(departments),
        "Salary": f"Rs.{random.randint(40000, 100000)}/-",
        "Skills": f"{skills}",  # Multiple skills
        "Experience": experiences  # Multiple experiences
    }

    employees.append(employee)

# display details of employees
print(json.dumps(employees, indent=2))
# Out:
# How much employees data you want?: 100
# [
#   {
#     "ID": "Emp1",
#     "Name": "hafsa",
#     "Age": 29,
#     "Department": "Sales",
#     "Salary": "Rs.81490/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.80686/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp2",
#     "Name": "manahil",
#     "Age": 53,
#     "Department": "HR",
#     "Salary": "Rs.80095/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Marketing",
#         "Salary": "Rs.94164/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Software Engineering",
#         "Salary": "Rs.88194/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp3",
#     "Name": "meheen",
#     "Age": 55,
#     "Department": "Sales",
#     "Salary": "Rs.75213/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Software Engineering",
#         "Salary": "Rs.93762/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.97591/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp4",
#     "Name": "hafsa",
#     "Age": 55,
#     "Department": "Accounts",
#     "Salary": "Rs.78861/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "HR",
#         "Salary": "Rs.52615/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.44971/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.58041/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp5",
#     "Name": "maliha",
#     "Age": 22,
#     "Department": "Marketing",
#     "Salary": "Rs.58021/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Sales",
#         "Salary": "Rs.77847/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Software Engineering",
#         "Salary": "Rs.89774/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.59432/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp6",
#     "Name": "zara",
#     "Age": 44,
#     "Department": "Sales",
#     "Salary": "Rs.98809/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.75615/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp7",
#     "Name": "manahil",
#     "Age": 23,
#     "Department": "Marketing",
#     "Salary": "Rs.76719/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.92458/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.69737/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp8",
#     "Name": "mehr",
#     "Age": 31,
#     "Department": "Sales",
#     "Salary": "Rs.85443/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.93974/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "HR",
#         "Salary": "Rs.96630/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Sales",
#         "Salary": "Rs.81067/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp9",
#     "Name": "zara",
#     "Age": 43,
#     "Department": "Marketing",
#     "Salary": "Rs.45913/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.91603/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.49932/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp10",
#     "Name": "maliha",
#     "Age": 35,
#     "Department": "Sales",
#     "Salary": "Rs.60981/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Accounts",
#         "Salary": "Rs.48395/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Accounts",
#         "Salary": "Rs.85792/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp11",
#     "Name": "manahil",
#     "Age": 30,
#     "Department": "Software Engineering",
#     "Salary": "Rs.84242/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Marketing",
#         "Salary": "Rs.71922/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.61646/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Software Engineering",
#         "Salary": "Rs.88040/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp12",
#     "Name": "maliha",
#     "Age": 20,
#     "Department": "Accounts",
#     "Salary": "Rs.43507/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Accounts",
#         "Salary": "Rs.73799/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.40216/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.58692/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp13",
#     "Name": "maliha",
#     "Age": 22,
#     "Department": "Software Engineering",
#     "Salary": "Rs.68058/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Accounts",
#         "Salary": "Rs.91335/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Marketing",
#         "Salary": "Rs.89159/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp14",
#     "Name": "aqsa",
#     "Age": 39,
#     "Department": "Accounts",
#     "Salary": "Rs.87552/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.97363/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp15",
#     "Name": "mehr",
#     "Age": 55,
#     "Department": "HR",
#     "Salary": "Rs.80987/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.56512/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp16",
#     "Name": "hafsa",
#     "Age": 57,
#     "Department": "HR",
#     "Salary": "Rs.45304/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "HR",
#         "Salary": "Rs.61344/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp17",
#     "Name": "maliha",
#     "Age": 43,
#     "Department": "Sales",
#     "Salary": "Rs.85349/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.96270/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.86153/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp18",
#     "Name": "manahil",
#     "Age": 48,
#     "Department": "Sales",
#     "Salary": "Rs.44712/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.40285/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Sales",
#         "Salary": "Rs.55094/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp19",
#     "Name": "mehr",
#     "Age": 21,
#     "Department": "Sales",
#     "Salary": "Rs.83156/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Sales",
#         "Salary": "Rs.47338/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.45375/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp20",
#     "Name": "kinza",
#     "Age": 50,
#     "Department": "Accounts",
#     "Salary": "Rs.86781/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.87531/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Accounts",
#         "Salary": "Rs.44007/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.72107/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp21",
#     "Name": "kinza",
#     "Age": 57,
#     "Department": "Sales",
#     "Salary": "Rs.75579/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Software Engineering",
#         "Salary": "Rs.52382/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.73936/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp22",
#     "Name": "aqsa",
#     "Age": 21,
#     "Department": "Sales",
#     "Salary": "Rs.84493/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.43323/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.91585/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp23",
#     "Name": "meheen",
#     "Age": 34,
#     "Department": "Software Engineering",
#     "Salary": "Rs.61530/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.72828/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Software Engineering",
#         "Salary": "Rs.60214/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Sales",
#         "Salary": "Rs.85548/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp24",
#     "Name": "zara",
#     "Age": 51,
#     "Department": "HR",
#     "Salary": "Rs.94096/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.92682/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.48538/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Software Engineering",
#         "Salary": "Rs.57994/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp25",
#     "Name": "aqsa",
#     "Age": 20,
#     "Department": "Accounts",
#     "Salary": "Rs.70259/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.57543/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.84052/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Marketing",
#         "Salary": "Rs.84250/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp26",
#     "Name": "kinza",
#     "Age": 38,
#     "Department": "Sales",
#     "Salary": "Rs.64319/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.50916/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp27",
#     "Name": "aqsa",
#     "Age": 40,
#     "Department": "Sales",
#     "Salary": "Rs.69387/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.82902/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.64723/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.95804/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp28",
#     "Name": "hafsa",
#     "Age": 37,
#     "Department": "Sales",
#     "Salary": "Rs.67173/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.77084/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.81917/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp29",
#     "Name": "meheen",
#     "Age": 36,
#     "Department": "Marketing",
#     "Salary": "Rs.49172/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.41604/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.63264/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.62299/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp30",
#     "Name": "kinza",
#     "Age": 25,
#     "Department": "Accounts",
#     "Salary": "Rs.66189/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Marketing",
#         "Salary": "Rs.89704/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp31",
#     "Name": "aqsa",
#     "Age": 31,
#     "Department": "Accounts",
#     "Salary": "Rs.91986/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.56230/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.44314/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp32",
#     "Name": "meheen",
#     "Age": 30,
#     "Department": "Sales",
#     "Salary": "Rs.95818/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Software Engineering",
#         "Salary": "Rs.60093/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Software Engineering",
#         "Salary": "Rs.71760/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp33",
#     "Name": "manahil",
#     "Age": 25,
#     "Department": "Sales",
#     "Salary": "Rs.52340/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.95447/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp34",
#     "Name": "meheen",
#     "Age": 44,
#     "Department": "Marketing",
#     "Salary": "Rs.48756/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.67256/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "HR",
#         "Salary": "Rs.48666/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.42643/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp35",
#     "Name": "maliha",
#     "Age": 50,
#     "Department": "HR",
#     "Salary": "Rs.61975/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Sales",
#         "Salary": "Rs.82153/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.71022/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Software Engineering",
#         "Salary": "Rs.58609/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp36",
#     "Name": "mehr",
#     "Age": 59,
#     "Department": "HR",
#     "Salary": "Rs.50183/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.51755/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp37",
#     "Name": "mehr",
#     "Age": 26,
#     "Department": "Software Engineering",
#     "Salary": "Rs.78543/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.96189/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp38",
#     "Name": "meheen",
#     "Age": 37,
#     "Department": "Sales",
#     "Salary": "Rs.52310/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.63995/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.60164/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.55570/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp39",
#     "Name": "zara",
#     "Age": 44,
#     "Department": "Marketing",
#     "Salary": "Rs.67781/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Sales",
#         "Salary": "Rs.55773/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.75330/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.75362/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp40",
#     "Name": "mehr",
#     "Age": 36,
#     "Department": "Accounts",
#     "Salary": "Rs.66109/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Accounts",
#         "Salary": "Rs.85122/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.98822/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp41",
#     "Name": "mehr",
#     "Age": 55,
#     "Department": "HR",
#     "Salary": "Rs.59907/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Marketing",
#         "Salary": "Rs.60796/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.97073/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp42",
#     "Name": "maliha",
#     "Age": 58,
#     "Department": "Sales",
#     "Salary": "Rs.51316/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Accounts",
#         "Salary": "Rs.77683/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Accounts",
#         "Salary": "Rs.80257/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp43",
#     "Name": "maliha",
#     "Age": 45,
#     "Department": "Sales",
#     "Salary": "Rs.73949/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Software Engineering",
#         "Salary": "Rs.88360/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.49244/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.96558/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp44",
#     "Name": "maliha",
#     "Age": 49,
#     "Department": "Software Engineering",
#     "Salary": "Rs.96043/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.74444/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.99371/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.67043/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp45",
#     "Name": "manahil",
#     "Age": 21,
#     "Department": "Software Engineering",
#     "Salary": "Rs.55729/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Marketing",
#         "Salary": "Rs.72414/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp46",
#     "Name": "zara",
#     "Age": 47,
#     "Department": "HR",
#     "Salary": "Rs.67441/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.57121/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.53862/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp47",
#     "Name": "manahil",
#     "Age": 43,
#     "Department": "Software Engineering",
#     "Salary": "Rs.73751/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Marketing",
#         "Salary": "Rs.49610/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "HR",
#         "Salary": "Rs.61541/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp48",
#     "Name": "zara",
#     "Age": 50,
#     "Department": "Accounts",
#     "Salary": "Rs.89272/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.84326/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.58150/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp49",
#     "Name": "manahil",
#     "Age": 49,
#     "Department": "Software Engineering",
#     "Salary": "Rs.44816/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.85888/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp50",
#     "Name": "kinza",
#     "Age": 42,
#     "Department": "Sales",
#     "Salary": "Rs.82526/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Software Engineering",
#         "Salary": "Rs.88998/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Software Engineering",
#         "Salary": "Rs.66423/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp51",
#     "Name": "hafsa",
#     "Age": 59,
#     "Department": "Marketing",
#     "Salary": "Rs.93290/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.55002/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.57275/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp52",
#     "Name": "meheen",
#     "Age": 57,
#     "Department": "Sales",
#     "Salary": "Rs.54725/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.76870/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Marketing",
#         "Salary": "Rs.79707/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.88528/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp53",
#     "Name": "mehr",
#     "Age": 28,
#     "Department": "Software Engineering",
#     "Salary": "Rs.66705/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.61651/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.99303/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.89252/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp54",
#     "Name": "zara",
#     "Age": 31,
#     "Department": "Software Engineering",
#     "Salary": "Rs.55561/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "HR",
#         "Salary": "Rs.58463/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.92967/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.40461/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp55",
#     "Name": "manahil",
#     "Age": 34,
#     "Department": "Accounts",
#     "Salary": "Rs.46527/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "HR",
#         "Salary": "Rs.66147/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Marketing",
#         "Salary": "Rs.40130/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Sales",
#         "Salary": "Rs.41539/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp56",
#     "Name": "aqsa",
#     "Age": 25,
#     "Department": "Accounts",
#     "Salary": "Rs.43642/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.67620/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Sales",
#         "Salary": "Rs.85098/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Software Engineering",
#         "Salary": "Rs.87124/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp57",
#     "Name": "kinza",
#     "Age": 47,
#     "Department": "Marketing",
#     "Salary": "Rs.97807/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.69064/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp58",
#     "Name": "aqsa",
#     "Age": 49,
#     "Department": "Sales",
#     "Salary": "Rs.67629/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.43199/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp59",
#     "Name": "kinza",
#     "Age": 38,
#     "Department": "HR",
#     "Salary": "Rs.89785/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.72252/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Software Engineering",
#         "Salary": "Rs.44953/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "HR",
#         "Salary": "Rs.62921/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp60",
#     "Name": "maliha",
#     "Age": 34,
#     "Department": "Software Engineering",
#     "Salary": "Rs.97253/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.80685/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Marketing",
#         "Salary": "Rs.50355/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Software Engineering",
#         "Salary": "Rs.94728/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp61",
#     "Name": "aqsa",
#     "Age": 39,
#     "Department": "Accounts",
#     "Salary": "Rs.47391/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Sales",
#         "Salary": "Rs.69558/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.68669/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp62",
#     "Name": "zara",
#     "Age": 52,
#     "Department": "Sales",
#     "Salary": "Rs.47944/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.45177/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp63",
#     "Name": "hafsa",
#     "Age": 57,
#     "Department": "HR",
#     "Salary": "Rs.79663/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.64908/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.47605/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.75872/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp64",
#     "Name": "aqsa",
#     "Age": 24,
#     "Department": "Software Engineering",
#     "Salary": "Rs.87042/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.41082/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp65",
#     "Name": "hafsa",
#     "Age": 20,
#     "Department": "Accounts",
#     "Salary": "Rs.90481/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.91588/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp66",
#     "Name": "meheen",
#     "Age": 23,
#     "Department": "HR",
#     "Salary": "Rs.59945/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Software Engineering",
#         "Salary": "Rs.40222/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp67",
#     "Name": "hafsa",
#     "Age": 60,
#     "Department": "Accounts",
#     "Salary": "Rs.53806/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.78360/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "HR",
#         "Salary": "Rs.78107/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "HR",
#         "Salary": "Rs.71897/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp68",
#     "Name": "kinza",
#     "Age": 40,
#     "Department": "Software Engineering",
#     "Salary": "Rs.49771/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.80654/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.82711/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp69",
#     "Name": "meheen",
#     "Age": 27,
#     "Department": "HR",
#     "Salary": "Rs.45192/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Accounts",
#         "Salary": "Rs.84378/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "HR",
#         "Salary": "Rs.41757/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp70",
#     "Name": "manahil",
#     "Age": 44,
#     "Department": "Software Engineering",
#     "Salary": "Rs.69678/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.52277/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp71",
#     "Name": "mehr",
#     "Age": 55,
#     "Department": "Sales",
#     "Salary": "Rs.89683/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.75997/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.66932/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.40464/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp72",
#     "Name": "hafsa",
#     "Age": 22,
#     "Department": "Sales",
#     "Salary": "Rs.55755/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.56086/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp73",
#     "Name": "hafsa",
#     "Age": 44,
#     "Department": "Software Engineering",
#     "Salary": "Rs.86057/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.40774/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.70977/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp74",
#     "Name": "maliha",
#     "Age": 31,
#     "Department": "Accounts",
#     "Salary": "Rs.87697/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.80020/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Marketing",
#         "Salary": "Rs.58261/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Sales",
#         "Salary": "Rs.47703/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp75",
#     "Name": "kinza",
#     "Age": 59,
#     "Department": "Accounts",
#     "Salary": "Rs.53337/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.78191/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp76",
#     "Name": "kinza",
#     "Age": 40,
#     "Department": "Software Engineering",
#     "Salary": "Rs.55497/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.67325/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp77",
#     "Name": "manahil",
#     "Age": 43,
#     "Department": "HR",
#     "Salary": "Rs.55527/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Accounts",
#         "Salary": "Rs.54664/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Accounts",
#         "Salary": "Rs.56083/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Accounts",
#         "Salary": "Rs.76014/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp78",
#     "Name": "zara",
#     "Age": 34,
#     "Department": "Accounts",
#     "Salary": "Rs.48407/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Marketing",
#         "Salary": "Rs.59294/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.71788/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp79",
#     "Name": "mehr",
#     "Age": 30,
#     "Department": "Accounts",
#     "Salary": "Rs.66800/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Marketing",
#         "Salary": "Rs.72786/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp80",
#     "Name": "zara",
#     "Age": 59,
#     "Department": "Marketing",
#     "Salary": "Rs.94142/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.64291/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp81",
#     "Name": "mehr",
#     "Age": 44,
#     "Department": "Accounts",
#     "Salary": "Rs.88918/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Sales",
#         "Salary": "Rs.97566/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.50848/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.45236/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp82",
#     "Name": "zara",
#     "Age": 50,
#     "Department": "Accounts",
#     "Salary": "Rs.76387/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "HR",
#         "Salary": "Rs.43874/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.46447/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp83",
#     "Name": "zara",
#     "Age": 28,
#     "Department": "HR",
#     "Salary": "Rs.93001/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.45027/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp84",
#     "Name": "kinza",
#     "Age": 54,
#     "Department": "HR",
#     "Salary": "Rs.55522/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.73502/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.61704/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.94739/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp85",
#     "Name": "zara",
#     "Age": 37,
#     "Department": "Sales",
#     "Salary": "Rs.82352/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Software Engineering",
#         "Salary": "Rs.97448/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp86",
#     "Name": "mehr",
#     "Age": 31,
#     "Department": "Sales",
#     "Salary": "Rs.64313/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.76586/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Marketing",
#         "Salary": "Rs.51388/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.89882/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp87",
#     "Name": "kinza",
#     "Age": 54,
#     "Department": "Sales",
#     "Salary": "Rs.51181/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.40380/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp88",
#     "Name": "manahil",
#     "Age": 49,
#     "Department": "Accounts",
#     "Salary": "Rs.59464/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Accounts",
#         "Salary": "Rs.71912/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.86556/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp89",
#     "Name": "kinza",
#     "Age": 27,
#     "Department": "Accounts",
#     "Salary": "Rs.43988/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.73868/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Software Engineering",
#         "Salary": "Rs.63386/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.85130/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp90",
#     "Name": "hafsa",
#     "Age": 34,
#     "Department": "HR",
#     "Salary": "Rs.68957/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Software Engineering",
#         "Salary": "Rs.47582/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.62806/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Marketing",
#         "Salary": "Rs.78115/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp91",
#     "Name": "zara",
#     "Age": 49,
#     "Department": "HR",
#     "Salary": "Rs.58842/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "HR",
#         "Salary": "Rs.55685/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.81665/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp92",
#     "Name": "kinza",
#     "Age": 43,
#     "Department": "Accounts",
#     "Salary": "Rs.67626/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.40361/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.81500/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.92461/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp93",
#     "Name": "meheen",
#     "Age": 43,
#     "Department": "Software Engineering",
#     "Salary": "Rs.58691/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.82556/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Software Engineering",
#         "Salary": "Rs.89528/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp94",
#     "Name": "hafsa",
#     "Age": 47,
#     "Department": "Marketing",
#     "Salary": "Rs.70745/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.95317/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp95",
#     "Name": "mehr",
#     "Age": 42,
#     "Department": "Sales",
#     "Salary": "Rs.70305/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Marketing",
#         "Salary": "Rs.99289/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.72813/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "HR",
#         "Salary": "Rs.83569/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp96",
#     "Name": "hafsa",
#     "Age": 32,
#     "Department": "Software Engineering",
#     "Salary": "Rs.51721/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.51792/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.83044/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp97",
#     "Name": "zara",
#     "Age": 50,
#     "Department": "Sales",
#     "Salary": "Rs.61422/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.60755/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp98",
#     "Name": "hafsa",
#     "Age": 50,
#     "Department": "Accounts",
#     "Salary": "Rs.49342/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.51791/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.87899/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp99",
#     "Name": "mehr",
#     "Age": 46,
#     "Department": "Accounts",
#     "Salary": "Rs.51509/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.87666/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "HR",
#         "Salary": "Rs.85173/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.41765/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp100",
#     "Name": "maliha",
#     "Age": 47,
#     "Department": "Sales",
#     "Salary": "Rs.61808/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.56305/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.71982/-"
#       }
#     ]
#   }
# ]

# %%
#update 1 employee name
employees[1]['Name'] = 'meheen'

# %%
print(json.dumps(employees[1], indent=2))
# Out:
# {
#   "ID": "Emp2",
#   "Name": "meheen",
#   "Department": "Marketing",
#   "Salary": "Rs.90070/-",
#   "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#   "Experience": [
#     {
#       "Company_Id": "C004",
#       "Age": 44,
#       "Department": "HR",
#       "Salary": "Rs.48671/-"
#     }
#   ]
# }

# %%
#display employee 3,4 experience
print(json.dumps([employees[3]["Experience"] ,employees[4]["Experience"]], indent=2))
# Out:
# [
#   [
#     {
#       "Company_Id": "C009",
#       "Age": 59,
#       "Department": "Software Engineering",
#       "Salary": "Rs.84251/-"
#     },
#     {
#       "Company_Id": "C006",
#       "Age": 33,
#       "Department": "Software Engineering",
#       "Salary": "Rs.51714/-"
#     },
#     {
#       "Company_Id": "C002",
#       "Age": 34,
#       "Department": "Sales",
#       "Salary": "Rs.51177/-"
#     }
#   ],
#   [
#     {
#       "Company_Id": "C001",
#       "Age": 52,
#       "Department": "Software Engineering",
#       "Salary": "Rs.96669/-"
#     }
#   ]
# ]

# %%
#display employee 6,7 experience salary
print(json.dumps([employees[6]["Experience"][0]["Salary"] ,employees[7]["Experience"][0]["Salary"]], indent=2))
# Out:
# [
#   "Rs.81532/-",
#   "Rs.81763/-"
# ]

# %%
#add new employee
new_employee = {
    "ID": "Emp101",
    "Name": "addUser",
    "Department": "Software Engineering",
    "Salary": "Rs.80000/-",
    "Skills": "['html', 'css', 'JavaScript']",
    "Experience": [
        {
            "Company_Id": "C001",
            "Age":34,
            "Department": "HR",
            "Salary": "Rs.50000/-"
        },
        {
            "Company_Id": "C002",
            "Age":34,
            "Department": "Software Engineering",
            "Salary": "Rs.60000/-"
        }
    ]
}
employees.append(new_employee)

# %%
employees[101]
# Out:
# {'ID': 'Emp101',
#  'Name': 'addUser',
#  'Department': 'Software Engineering',
#  'Salary': 'Rs.80000/-',
#  'Skills': "['html', 'css', 'JavaScript']",
#  'Experience': [{'Company_Id': 'C001',
#    'Age': 34,
#    'Department': 'HR',
#    'Salary': 'Rs.50000/-'},
#   {'Company_Id': 'C002',
#    'Age': 34,
#    'Department': 'Software Engineering',
#    'Salary': 'Rs.60000/-'}]}

# %% [markdown]
# **SAME CODE BY USING FUNCTIONS**

# %%
import random
import json

# Sample data
names = ["maliha", "meheen", "hafsa", "manahil", "zara", "mehr", "aqsa", "kinza"]
departments = ["HR", "Software Engineering", "Marketing", "Sales", "Accounts"]
skills = ["html", "css", "JavaScript", "python", "ai engineer", "data science", "next js"]
company_ids = ["C001", "C002", "C003", "C004", "C005", "C006", "C007", "C008", "C009", "C010"]
count=int(input("How much employees data you want?: "))
# Function to generate random experiences
def generate_experiences():
    experiences = []
    for i in range(random.randint(1, 3)):  # Each employee has 1 to 3 experiences
        experience = {
            "Company_Id": random.choice(company_ids),
            "Department": random.choice(departments),
            "Salary": f"Rs.{random.randint(40000, 100000)}/-"
        }
        experiences.append(experience)
    return experiences

# Function to generate a single employee
def generate_employee(emp_id):
    employee = {
        "ID": f"Emp{emp_id}",
        "Name": random.choice(names),
        "Age": random.randint(20, 60),
        "Department": random.choice(departments),
        "Salary": f"Rs.{random.randint(40000, 100000)}/-",
        "Skills":f"{skills}",  # Select 2–4 random skills
        "Experience": generate_experiences()
    }
    return employee

# Function to generate all employees
def generate_employees(count):
    employees = []
    for i in range(1, count + 1):
        employee = generate_employee(i)
        employees.append(employee)
    return employees

# Function to display employees in JSON format
def display_employees(employees):
    print(json.dumps(employees, indent=2))

# Call for function
employees = generate_employees(count)
display_employees(employees)
# Out:
# How much employees data you want?: 100
# [
#   {
#     "ID": "Emp1",
#     "Name": "zara",
#     "Age": 57,
#     "Department": "Sales",
#     "Salary": "Rs.98469/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Software Engineering",
#         "Salary": "Rs.77713/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Software Engineering",
#         "Salary": "Rs.71313/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Marketing",
#         "Salary": "Rs.86190/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp2",
#     "Name": "manahil",
#     "Age": 44,
#     "Department": "Accounts",
#     "Salary": "Rs.87219/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.78264/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp3",
#     "Name": "manahil",
#     "Age": 30,
#     "Department": "Software Engineering",
#     "Salary": "Rs.49392/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.61081/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp4",
#     "Name": "kinza",
#     "Age": 27,
#     "Department": "HR",
#     "Salary": "Rs.75114/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.76894/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Software Engineering",
#         "Salary": "Rs.45180/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.99059/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp5",
#     "Name": "kinza",
#     "Age": 56,
#     "Department": "Sales",
#     "Salary": "Rs.47787/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.83585/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp6",
#     "Name": "manahil",
#     "Age": 55,
#     "Department": "HR",
#     "Salary": "Rs.92903/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.55769/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Software Engineering",
#         "Salary": "Rs.64867/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Accounts",
#         "Salary": "Rs.45730/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp7",
#     "Name": "kinza",
#     "Age": 59,
#     "Department": "Sales",
#     "Salary": "Rs.44236/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.46348/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.69231/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.42001/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp8",
#     "Name": "aqsa",
#     "Age": 38,
#     "Department": "HR",
#     "Salary": "Rs.97910/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Accounts",
#         "Salary": "Rs.86398/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.41890/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.70253/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp9",
#     "Name": "mehr",
#     "Age": 60,
#     "Department": "Sales",
#     "Salary": "Rs.81017/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Accounts",
#         "Salary": "Rs.62657/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Marketing",
#         "Salary": "Rs.74235/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp10",
#     "Name": "mehr",
#     "Age": 24,
#     "Department": "Marketing",
#     "Salary": "Rs.90224/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.70429/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.60109/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.76261/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp11",
#     "Name": "kinza",
#     "Age": 33,
#     "Department": "Accounts",
#     "Salary": "Rs.59429/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Accounts",
#         "Salary": "Rs.91687/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp12",
#     "Name": "maliha",
#     "Age": 59,
#     "Department": "Accounts",
#     "Salary": "Rs.45324/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.76131/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.68810/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp13",
#     "Name": "hafsa",
#     "Age": 55,
#     "Department": "Accounts",
#     "Salary": "Rs.88735/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.61603/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.60334/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp14",
#     "Name": "maliha",
#     "Age": 26,
#     "Department": "Marketing",
#     "Salary": "Rs.75918/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.98097/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp15",
#     "Name": "maliha",
#     "Age": 54,
#     "Department": "Accounts",
#     "Salary": "Rs.50068/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.90623/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp16",
#     "Name": "manahil",
#     "Age": 36,
#     "Department": "Sales",
#     "Salary": "Rs.58168/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.68649/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp17",
#     "Name": "meheen",
#     "Age": 52,
#     "Department": "Sales",
#     "Salary": "Rs.86127/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.90272/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp18",
#     "Name": "mehr",
#     "Age": 58,
#     "Department": "Accounts",
#     "Salary": "Rs.58420/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "HR",
#         "Salary": "Rs.71072/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp19",
#     "Name": "meheen",
#     "Age": 33,
#     "Department": "HR",
#     "Salary": "Rs.88101/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.72795/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp20",
#     "Name": "kinza",
#     "Age": 27,
#     "Department": "Marketing",
#     "Salary": "Rs.60798/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.99582/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Marketing",
#         "Salary": "Rs.73593/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.77255/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp21",
#     "Name": "meheen",
#     "Age": 38,
#     "Department": "Accounts",
#     "Salary": "Rs.83666/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Accounts",
#         "Salary": "Rs.62551/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp22",
#     "Name": "mehr",
#     "Age": 23,
#     "Department": "Marketing",
#     "Salary": "Rs.87231/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Sales",
#         "Salary": "Rs.79938/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp23",
#     "Name": "maliha",
#     "Age": 48,
#     "Department": "Marketing",
#     "Salary": "Rs.92587/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "HR",
#         "Salary": "Rs.52083/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.59140/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp24",
#     "Name": "hafsa",
#     "Age": 53,
#     "Department": "Accounts",
#     "Salary": "Rs.58027/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.80139/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp25",
#     "Name": "hafsa",
#     "Age": 34,
#     "Department": "Software Engineering",
#     "Salary": "Rs.92823/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.86763/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.70956/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.60653/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp26",
#     "Name": "mehr",
#     "Age": 20,
#     "Department": "Marketing",
#     "Salary": "Rs.59902/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.98203/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.48350/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp27",
#     "Name": "mehr",
#     "Age": 47,
#     "Department": "HR",
#     "Salary": "Rs.55501/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Software Engineering",
#         "Salary": "Rs.41607/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.53927/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.62623/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp28",
#     "Name": "hafsa",
#     "Age": 26,
#     "Department": "HR",
#     "Salary": "Rs.61710/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.49339/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp29",
#     "Name": "hafsa",
#     "Age": 52,
#     "Department": "Sales",
#     "Salary": "Rs.59983/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Accounts",
#         "Salary": "Rs.75051/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp30",
#     "Name": "manahil",
#     "Age": 21,
#     "Department": "Software Engineering",
#     "Salary": "Rs.82926/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Sales",
#         "Salary": "Rs.83729/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Marketing",
#         "Salary": "Rs.75328/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.74882/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp31",
#     "Name": "hafsa",
#     "Age": 58,
#     "Department": "Accounts",
#     "Salary": "Rs.45582/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.66457/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.82599/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp32",
#     "Name": "maliha",
#     "Age": 58,
#     "Department": "Marketing",
#     "Salary": "Rs.57075/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "HR",
#         "Salary": "Rs.99988/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.51042/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp33",
#     "Name": "meheen",
#     "Age": 44,
#     "Department": "Marketing",
#     "Salary": "Rs.51643/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.94377/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Software Engineering",
#         "Salary": "Rs.84441/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp34",
#     "Name": "manahil",
#     "Age": 58,
#     "Department": "Software Engineering",
#     "Salary": "Rs.75179/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Marketing",
#         "Salary": "Rs.49186/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp35",
#     "Name": "maliha",
#     "Age": 53,
#     "Department": "Software Engineering",
#     "Salary": "Rs.98303/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Accounts",
#         "Salary": "Rs.43794/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.89689/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp36",
#     "Name": "kinza",
#     "Age": 55,
#     "Department": "Sales",
#     "Salary": "Rs.72547/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.45058/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.79602/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "HR",
#         "Salary": "Rs.51365/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp37",
#     "Name": "mehr",
#     "Age": 24,
#     "Department": "Accounts",
#     "Salary": "Rs.91971/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Marketing",
#         "Salary": "Rs.46541/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.86628/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp38",
#     "Name": "maliha",
#     "Age": 54,
#     "Department": "Software Engineering",
#     "Salary": "Rs.55046/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.74422/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.42871/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Software Engineering",
#         "Salary": "Rs.45667/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp39",
#     "Name": "manahil",
#     "Age": 49,
#     "Department": "Accounts",
#     "Salary": "Rs.59815/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Marketing",
#         "Salary": "Rs.72403/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.52308/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.54634/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp40",
#     "Name": "aqsa",
#     "Age": 32,
#     "Department": "Software Engineering",
#     "Salary": "Rs.82205/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.80500/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp41",
#     "Name": "maliha",
#     "Age": 37,
#     "Department": "Marketing",
#     "Salary": "Rs.91520/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.58889/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp42",
#     "Name": "aqsa",
#     "Age": 54,
#     "Department": "Software Engineering",
#     "Salary": "Rs.49640/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.54540/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Software Engineering",
#         "Salary": "Rs.43441/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp43",
#     "Name": "hafsa",
#     "Age": 36,
#     "Department": "Sales",
#     "Salary": "Rs.43334/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "HR",
#         "Salary": "Rs.50706/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.49473/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp44",
#     "Name": "zara",
#     "Age": 60,
#     "Department": "Sales",
#     "Salary": "Rs.44599/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.65239/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp45",
#     "Name": "meheen",
#     "Age": 52,
#     "Department": "Marketing",
#     "Salary": "Rs.58018/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.84456/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Sales",
#         "Salary": "Rs.47203/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp46",
#     "Name": "zara",
#     "Age": 60,
#     "Department": "Software Engineering",
#     "Salary": "Rs.70174/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.54253/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp47",
#     "Name": "maliha",
#     "Age": 35,
#     "Department": "Marketing",
#     "Salary": "Rs.88404/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.60683/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Marketing",
#         "Salary": "Rs.65091/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.87444/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp48",
#     "Name": "kinza",
#     "Age": 46,
#     "Department": "Sales",
#     "Salary": "Rs.51655/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.72499/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.62162/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.57185/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp49",
#     "Name": "manahil",
#     "Age": 48,
#     "Department": "Marketing",
#     "Salary": "Rs.65038/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.68879/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp50",
#     "Name": "manahil",
#     "Age": 44,
#     "Department": "Software Engineering",
#     "Salary": "Rs.85807/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.89290/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp51",
#     "Name": "zara",
#     "Age": 30,
#     "Department": "Marketing",
#     "Salary": "Rs.82839/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.65399/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.70911/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.44798/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp52",
#     "Name": "manahil",
#     "Age": 21,
#     "Department": "HR",
#     "Salary": "Rs.52844/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.51962/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.71441/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.71912/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp53",
#     "Name": "hafsa",
#     "Age": 31,
#     "Department": "Software Engineering",
#     "Salary": "Rs.96999/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Software Engineering",
#         "Salary": "Rs.40879/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.47400/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp54",
#     "Name": "mehr",
#     "Age": 34,
#     "Department": "Software Engineering",
#     "Salary": "Rs.53680/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Software Engineering",
#         "Salary": "Rs.41941/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.73102/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Sales",
#         "Salary": "Rs.68059/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp55",
#     "Name": "kinza",
#     "Age": 33,
#     "Department": "Software Engineering",
#     "Salary": "Rs.77467/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "HR",
#         "Salary": "Rs.64329/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Sales",
#         "Salary": "Rs.87481/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "HR",
#         "Salary": "Rs.90211/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp56",
#     "Name": "mehr",
#     "Age": 31,
#     "Department": "HR",
#     "Salary": "Rs.59840/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Marketing",
#         "Salary": "Rs.62607/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp57",
#     "Name": "maliha",
#     "Age": 33,
#     "Department": "Sales",
#     "Salary": "Rs.44701/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.87096/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.46925/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp58",
#     "Name": "meheen",
#     "Age": 29,
#     "Department": "Software Engineering",
#     "Salary": "Rs.47053/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.56353/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Accounts",
#         "Salary": "Rs.80876/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.93949/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp59",
#     "Name": "mehr",
#     "Age": 41,
#     "Department": "Marketing",
#     "Salary": "Rs.99265/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Software Engineering",
#         "Salary": "Rs.79721/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.47595/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp60",
#     "Name": "hafsa",
#     "Age": 54,
#     "Department": "Marketing",
#     "Salary": "Rs.55321/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.97132/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.95785/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp61",
#     "Name": "hafsa",
#     "Age": 30,
#     "Department": "Sales",
#     "Salary": "Rs.43376/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.54219/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.73966/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.73807/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp62",
#     "Name": "zara",
#     "Age": 21,
#     "Department": "Sales",
#     "Salary": "Rs.82172/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "Accounts",
#         "Salary": "Rs.60085/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.69419/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp63",
#     "Name": "maliha",
#     "Age": 46,
#     "Department": "Marketing",
#     "Salary": "Rs.81321/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.64381/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp64",
#     "Name": "aqsa",
#     "Age": 21,
#     "Department": "HR",
#     "Salary": "Rs.76789/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.98630/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp65",
#     "Name": "zara",
#     "Age": 28,
#     "Department": "Marketing",
#     "Salary": "Rs.79274/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Software Engineering",
#         "Salary": "Rs.58205/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp66",
#     "Name": "aqsa",
#     "Age": 21,
#     "Department": "Accounts",
#     "Salary": "Rs.43577/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "HR",
#         "Salary": "Rs.84935/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Sales",
#         "Salary": "Rs.41275/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp67",
#     "Name": "kinza",
#     "Age": 25,
#     "Department": "Accounts",
#     "Salary": "Rs.44795/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "HR",
#         "Salary": "Rs.75114/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Accounts",
#         "Salary": "Rs.80048/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp68",
#     "Name": "manahil",
#     "Age": 28,
#     "Department": "Software Engineering",
#     "Salary": "Rs.40782/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Sales",
#         "Salary": "Rs.40308/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.58366/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.86879/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp69",
#     "Name": "manahil",
#     "Age": 40,
#     "Department": "HR",
#     "Salary": "Rs.40339/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.80066/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.80909/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp70",
#     "Name": "mehr",
#     "Age": 30,
#     "Department": "Marketing",
#     "Salary": "Rs.68462/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.60306/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.48342/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp71",
#     "Name": "kinza",
#     "Age": 31,
#     "Department": "Accounts",
#     "Salary": "Rs.75739/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.49286/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp72",
#     "Name": "zara",
#     "Age": 27,
#     "Department": "HR",
#     "Salary": "Rs.90662/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.95279/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp73",
#     "Name": "manahil",
#     "Age": 34,
#     "Department": "Accounts",
#     "Salary": "Rs.76278/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Software Engineering",
#         "Salary": "Rs.74087/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Software Engineering",
#         "Salary": "Rs.69163/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Marketing",
#         "Salary": "Rs.62498/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp74",
#     "Name": "maliha",
#     "Age": 52,
#     "Department": "Sales",
#     "Salary": "Rs.92479/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.93178/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.69319/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.86124/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp75",
#     "Name": "kinza",
#     "Age": 32,
#     "Department": "Sales",
#     "Salary": "Rs.72637/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "HR",
#         "Salary": "Rs.95581/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp76",
#     "Name": "hafsa",
#     "Age": 44,
#     "Department": "Software Engineering",
#     "Salary": "Rs.85440/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C007",
#         "Department": "Marketing",
#         "Salary": "Rs.97039/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp77",
#     "Name": "hafsa",
#     "Age": 35,
#     "Department": "Marketing",
#     "Salary": "Rs.88382/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Accounts",
#         "Salary": "Rs.95733/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp78",
#     "Name": "manahil",
#     "Age": 44,
#     "Department": "Sales",
#     "Salary": "Rs.45864/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "HR",
#         "Salary": "Rs.68274/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Accounts",
#         "Salary": "Rs.55878/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp79",
#     "Name": "manahil",
#     "Age": 21,
#     "Department": "HR",
#     "Salary": "Rs.54962/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.54703/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "HR",
#         "Salary": "Rs.45773/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp80",
#     "Name": "hafsa",
#     "Age": 21,
#     "Department": "Accounts",
#     "Salary": "Rs.81859/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.54767/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.91330/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp81",
#     "Name": "maliha",
#     "Age": 30,
#     "Department": "Accounts",
#     "Salary": "Rs.45576/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Accounts",
#         "Salary": "Rs.81006/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "Marketing",
#         "Salary": "Rs.70259/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Accounts",
#         "Salary": "Rs.96218/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp82",
#     "Name": "maliha",
#     "Age": 52,
#     "Department": "Sales",
#     "Salary": "Rs.70572/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.68139/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "HR",
#         "Salary": "Rs.42554/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp83",
#     "Name": "kinza",
#     "Age": 24,
#     "Department": "Marketing",
#     "Salary": "Rs.73988/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.41418/-"
#       },
#       {
#         "Company_Id": "C009",
#         "Department": "Software Engineering",
#         "Salary": "Rs.64783/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp84",
#     "Name": "aqsa",
#     "Age": 38,
#     "Department": "Software Engineering",
#     "Salary": "Rs.80192/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.92190/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Sales",
#         "Salary": "Rs.55219/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp85",
#     "Name": "manahil",
#     "Age": 42,
#     "Department": "Sales",
#     "Salary": "Rs.92150/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "HR",
#         "Salary": "Rs.45242/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Software Engineering",
#         "Salary": "Rs.57706/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp86",
#     "Name": "meheen",
#     "Age": 24,
#     "Department": "HR",
#     "Salary": "Rs.50793/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Sales",
#         "Salary": "Rs.88594/-"
#       },
#       {
#         "Company_Id": "C002",
#         "Department": "Marketing",
#         "Salary": "Rs.70844/-"
#       },
#       {
#         "Company_Id": "C001",
#         "Department": "Software Engineering",
#         "Salary": "Rs.41944/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp87",
#     "Name": "hafsa",
#     "Age": 29,
#     "Department": "Sales",
#     "Salary": "Rs.66839/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C009",
#         "Department": "Marketing",
#         "Salary": "Rs.51216/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Software Engineering",
#         "Salary": "Rs.77096/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "HR",
#         "Salary": "Rs.96664/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp88",
#     "Name": "manahil",
#     "Age": 44,
#     "Department": "Software Engineering",
#     "Salary": "Rs.51945/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C004",
#         "Department": "Marketing",
#         "Salary": "Rs.42878/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Software Engineering",
#         "Salary": "Rs.90956/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp89",
#     "Name": "manahil",
#     "Age": 58,
#     "Department": "Software Engineering",
#     "Salary": "Rs.76354/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.61500/-"
#       },
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.74295/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp90",
#     "Name": "mehr",
#     "Age": 60,
#     "Department": "Marketing",
#     "Salary": "Rs.95146/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C006",
#         "Department": "HR",
#         "Salary": "Rs.75122/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp91",
#     "Name": "aqsa",
#     "Age": 53,
#     "Department": "HR",
#     "Salary": "Rs.81185/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "HR",
#         "Salary": "Rs.63484/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Accounts",
#         "Salary": "Rs.77301/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.49891/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp92",
#     "Name": "hafsa",
#     "Age": 24,
#     "Department": "Marketing",
#     "Salary": "Rs.92029/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C001",
#         "Department": "Marketing",
#         "Salary": "Rs.84884/-"
#       },
#       {
#         "Company_Id": "C010",
#         "Department": "Software Engineering",
#         "Salary": "Rs.61594/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.85659/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp93",
#     "Name": "hafsa",
#     "Age": 42,
#     "Department": "Accounts",
#     "Salary": "Rs.94045/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.56597/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Accounts",
#         "Salary": "Rs.62233/-"
#       },
#       {
#         "Company_Id": "C004",
#         "Department": "Software Engineering",
#         "Salary": "Rs.80831/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp94",
#     "Name": "mehr",
#     "Age": 35,
#     "Department": "Sales",
#     "Salary": "Rs.70142/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "HR",
#         "Salary": "Rs.40822/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp95",
#     "Name": "maliha",
#     "Age": 52,
#     "Department": "Accounts",
#     "Salary": "Rs.92117/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C010",
#         "Department": "Software Engineering",
#         "Salary": "Rs.64312/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.56045/-"
#       },
#       {
#         "Company_Id": "C006",
#         "Department": "Sales",
#         "Salary": "Rs.66998/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp96",
#     "Name": "manahil",
#     "Age": 33,
#     "Department": "Marketing",
#     "Salary": "Rs.82076/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Marketing",
#         "Salary": "Rs.46052/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Accounts",
#         "Salary": "Rs.98760/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp97",
#     "Name": "zara",
#     "Age": 50,
#     "Department": "Accounts",
#     "Salary": "Rs.87495/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Marketing",
#         "Salary": "Rs.83959/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp98",
#     "Name": "aqsa",
#     "Age": 52,
#     "Department": "HR",
#     "Salary": "Rs.90731/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C008",
#         "Department": "Software Engineering",
#         "Salary": "Rs.88021/-"
#       },
#       {
#         "Company_Id": "C007",
#         "Department": "Accounts",
#         "Salary": "Rs.61774/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp99",
#     "Name": "maliha",
#     "Age": 20,
#     "Department": "Accounts",
#     "Salary": "Rs.53024/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C003",
#         "Department": "Accounts",
#         "Salary": "Rs.79689/-"
#       }
#     ]
#   },
#   {
#     "ID": "Emp100",
#     "Name": "kinza",
#     "Age": 30,
#     "Department": "HR",
#     "Salary": "Rs.47383/-",
#     "Skills": "['html', 'css', 'JavaScript', 'python', 'ai engineer', 'data science', 'next js']",
#     "Experience": [
#       {
#         "Company_Id": "C005",
#         "Department": "HR",
#         "Salary": "Rs.89386/-"
#       },
#       {
#         "Company_Id": "C008",
#         "Department": "Sales",
#         "Salary": "Rs.68443/-"
#       },
#       {
#         "Company_Id": "C003",
#         "Department": "Sales",
#         "Salary": "Rs.53433/-"
#       }
#     ]
#   }
# ]
